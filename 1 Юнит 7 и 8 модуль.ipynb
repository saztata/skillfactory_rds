# %%
import pandas as pd
ratings = pd.read_csv('ratings.csv')
ratings.head()
ratings['rating'].max()
# Out:
# 5.0

# %%
import pandas as pd
movies = pd.read_csv('movies.csv')

display(movie)
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
import pandas as pd
ratings = pd.read_csv('ratings.csv')

ratings['rating'].max()
display(ratings)
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
joined = ratings.merge(movies, on='movieId', how='left')
joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
len(ratings) == len(joined)
# Out:
# True

# %%
import pandas as pd
ratings = pd.read_csv('ratings_example.txt', sep = '\t')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144

# %%
movies = pd.read_csv('movies_example.txt', sep = '\t')
movies.head()
# Out:
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 2       31                    Dangerous Minds (1995)                     Drama

# %%
ratings.merge(movies, how = 'left', on = 'movieId')
# Out:
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama
# 1       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
movies.head()
# Out:
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller

# %%
ratings.merge(movies, how = 'left', on = 'movieId')
# Out:
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}
items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

# %%
all_df=purchase_df.merge(items_df, how = 'left', on = 'item_id')
all_df['summ'] = (purchase_df['price'] * items_df['stock_count'])

all_df.sort_values('summ', axis=0, ascending=False)
# Out:
#    purchase_id  item_id  price   vendor  stock_count     summ
# 8          145   103845  89900      NaN          NaN  5394000
# 6          145   382043  67500  Samsung         77.0  5197500
# 7          145   302948  34500  Samsung        143.0  4933500
# 2          101   132223  38200    Apple        122.0  4660400
# 5          145  3294095  33000    Apple         43.0  1419000
# 4          121    19475   9890       LG        102.0  1008780
# 3          112   573943  49990    Apple         18.0   899820
# 0          101   417283  13900  Samsung         54.0   750600
# 9          221   100132  11400       LG         60.0   216600
# 1          101   849734   5330       LG         33.0   175890

# %%
all_df=purchase_df.merge(items_df, how = 'left', on = 'item_id')
all_df['summ'] = (purchase_df['price'] * items_df['stock_count'])

all_df.sort_values('summ', axis=0, ascending=False)
a=all_df['summ'].sum()
print(a)
# Out:
# 24656090

# %%
import os
files = os.listdir('data')
files
# Out:
# ['ratings_1.txt',
#  'ratings_10.txt',
#  'ratings_2.txt',
#  'ratings_3.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_6.txt',
#  'ratings_7.txt',
#  'ratings_8.txt',
#  'ratings_9.txt']

# %%
import re
files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
data1 = []
for file in files:
    if '.txt' in file:
        data1.append(file)       
print(data1)
# Out:
# ['ratings.txt', 'stock_stats.txt', 'movies.txt']

# %%
for root, dirs, files in os.walk('data'):
    print(root, dirs, files)
# Out:
# data [] ['ratings_1.txt', 'ratings_10.txt', 'ratings_2.txt', 'ratings_3.txt', 'ratings_4.txt', 'ratings_5.txt', 'ratings_6.txt', 'ratings_7.txt', 'ratings_8.txt', 'ratings_9.txt']

# %%
import os
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
files = os.listdir('data')
for filename in files:
    temp = pd.read_csv( os.path.join('data', filename), names = ['userId', 'movieId', 'rating', 'timestamp'] )
    data = pd.concat([data, temp])
len(data)
# Out:
# 100004

# %%
import pandas as pd
ratings = pd.read_csv('ratings.csv')

ratings[(ratings['rating']==0.5)].count()
# Out:
# userId       1370
# movieId      1370
# rating       1370
# timestamp    1370
# dtype: int64

# %%
import pandas as pd
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')
ratings.merge(movies, how = 'outer', on = 'movieId')
# Out:
#         userId  movieId  rating     timestamp  \
# 0          1.0        1     4.0  9.649827e+08
# 1          5.0        1     4.0  8.474350e+08
# 2          7.0        1     4.5  1.106636e+09
# 3         15.0        1     2.5  1.510578e+09
# 4         17.0        1     4.5  1.305696e+09
# ...        ...      ...     ...           ...
# 100849     NaN    30892     NaN           NaN
# 100850     NaN    32160     NaN           NaN
# 100851     NaN    32371     NaN           NaN
# 100852     NaN    34482     NaN           NaN
# 100853     NaN    85565     NaN           NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                         Toy Story (1995)
# 2                         Toy Story (1995)
# 3                         Toy Story (1995)
# 4                         Toy Story (1995)
# ...                                    ...
# 100849  In the Realms of the Unreal (2004)
# 100850            Twentieth Century (1934)
# ...

# %%
import pandas as pd
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')
rate=ratings.merge(movies, how = 'outer', on = 'movieId')
ratings['movieId']
movies[movies['movieId']==3456]
# Out:
#       movieId                                         title genres
# 2587     3456  Color of Paradise, The (Rang-e khoda) (1999)  Drama

# %%
import pandas as pd
log = pd.read_csv('log.csv',header=None)
log
# Out:
#                                     0                     1        2        3
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN      NaN
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      NaN
# 998                            #error                   NaN   1000.0      NaN
# 999                            #error                   NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
import pandas as pd
df = pd.read_csv('sample.csv')
df
# Out:
#             Name         City  Age Profession
# 0         Иванов       Москва   25     Клинер
# 1            NaN    Волгоград   31   Менеджер
# 2         Иванов       Москва   25     Клинер
# 3        sidorov  Владивосток   43   Менеджер
# 4        _______        Курск   50   Водитель
# 5       Кузнецов         Сочи   19    Рабочий
# 6          Сажин       Сургут   29    Рабочий
# 7   Котлеревский   Йошкар-Ола   32    Рабочий
# 8     Завалишина    Чебоксары   36   Менеджер
# 9         Левина          NaN   55    Рабочий
# 10          Фикс         Рига   42    Рабочий

# %%
df.columns
# Out:
# Index(['Name', 'City', 'Age', 'Profession'], dtype='object')

# %%
df.columns = ['new_col_name_1', 'new_col_name_2', 'new_col_name_3', 'new_col_name_4']

# %%
df
# Out:
#    new_col_name_1 new_col_name_2  new_col_name_3 new_col_name_4
# 0          Иванов         Москва              25         Клинер
# 1             NaN      Волгоград              31       Менеджер
# 2          Иванов         Москва              25         Клинер
# 3         sidorov    Владивосток              43       Менеджер
# 4         _______          Курск              50       Водитель
# 5        Кузнецов           Сочи              19        Рабочий
# 6           Сажин         Сургут              29        Рабочий
# 7    Котлеревский     Йошкар-Ола              32        Рабочий
# 8      Завалишина      Чебоксары              36       Менеджер
# 9          Левина            NaN              55        Рабочий
# 10           Фикс           Рига              42        Рабочий

# %%
import pandas as pd
sample = pd.read_csv('sample.csv')
columns=sample.columns
columns
# Out:
# Index(['Name', 'City', 'Age', 'Profession'], dtype='object')

# %%
sample.columns=['name','city','age','profession']

# %%
sample
# Out:
#             name         city  age profession
# 0         Иванов       Москва   25     Клинер
# 1            NaN    Волгоград   31   Менеджер
# 2         Иванов       Москва   25     Клинер
# 3        sidorov  Владивосток   43   Менеджер
# 4        _______        Курск   50   Водитель
# 5       Кузнецов         Сочи   19    Рабочий
# 6          Сажин       Сургут   29    Рабочий
# 7   Котлеревский   Йошкар-Ола   32    Рабочий
# 8     Завалишина    Чебоксары   36   Менеджер
# 9         Левина          NaN   55    Рабочий
# 10          Фикс         Рига   42    Рабочий

# %%
import pandas as pd
log = pd.read_csv('log.csv',header=None)
log.columns=['user_id','time','bet','win']
log
# Out:
#                               user_id                  time      bet      win
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN      NaN
# ..                                ...                   ...      ...      ...
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                            #error                   NaN  10054.0  29265.0
# 997                            #error                   NaN  10454.0      NaN
# 998                            #error                   NaN   1000.0      NaN
# 999                            #error                   NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
import pandas as pd
users = pd.read_csv('users.csv')
users.columns=['user_id','email','geo']
users
# Out:
#      user_id                     email  geo
# 0   User_943       Accumanst@gmail.com  NaN
# 1   User_908         Advismowr@mail.ru  NaN
# 2   User_962           Anachso@ukr.net  NaN
# 3   User_973          Antecia@inbox.ru  NaN
# 4   User_902        Balliaryva@ukr.net  NaN
# ..       ...                       ...  ...
# 95  User_959  UpdatesCurious@yahoo.com  NaN
# 96  User_901        V2artierso@mail.ru  NaN
# 97  User_970          Vashoterlo@bk.ru  NaN
# 98  User_965       Visuareda@yahoo.com  NaN
# 99  User_921              Aavast@ya.ru  NaN
#
# [100 rows x 3 columns]

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   user_id  100 non-null    object
#  1   email    99 non-null     object
#  2   geo      0 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB

# %%
sample.name.unique()
# Out:
# array(['Иванов', nan, 'sidorov', '_______', 'Кузнецов', 'Сажин',
#        'Котлеревский', 'Завалишина', 'Левина', 'Фикс'], dtype=object)

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        10 non-null     object
#  1   city        10 non-null     object
#  2   age         11 non-null     int64
#  3   profession  11 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 480.0+ bytes

# %%
sample = pd.read_csv('sample.csv')
sample2=sample[(sample['Age']<30)&(sample['Profession']=='Рабочий')]
sample2
# Out:
#        Name    City  Age Profession
# 5  Кузнецов    Сочи   19    Рабочий
# 6     Сажин  Сургут   29    Рабочий

# %%
log = pd.read_csv("log.csv",header=None)
log.columns = ['user_id','time', 'bet','win']
log_win = log[log['win']>0]
win_count=len(log_win)
win_count
# Out:
# 138

# %%
log = pd.read_csv("log.csv",header=None)
log.columns = ['user_id','time', 'bet','win']
log2=log.query('bet<2000 & win>0')
log2
# Out:
#                               user_id                  time     bet     win
# 151  Запись пользователя № - user_982  [2019-01-16 21:54:22   100.0  4749.0
# 189  Запись пользователя № - user_964  [2019-01-21 18:34:44   200.0  4667.0
# 205  Запись пользователя № - user_931   [2019-01-22 5:26:59   300.0  4319.0
# 232  Запись пользователя № - user_998   [2019-01-25 8:57:20   500.0  5069.0
# 265  Запись пользователя № - user_998  [2019-01-29 10:37:55   500.0  6294.0
# ..                                ...                   ...     ...     ...
# 962  Запись пользователя № - user_976  [2019-04-19 14:18:45   400.0  5997.0
# 965  Запись пользователя № - user_900  [2019-04-19 19:31:48   900.0  6767.0
# 967  Запись пользователя № - user_975  [2019-04-19 22:25:15  1000.0  6108.0
# 981                            #error                   NaN   800.0  7035.0
# 991  Запись пользователя № - user_965  [2019-04-20 12:55:41   800.0  6927.0
#
# [113 rows x 4 columns]

# %%
sample = pd.read_csv("sample.csv")
sample3=sample[sample.City.str.contains("о", na=False)]
sample3
# Out:
#            Name         City  Age Profession
# 0        Иванов       Москва   25     Клинер
# 1           NaN    Волгоград   31   Менеджер
# 2        Иванов       Москва   25     Клинер
# 3       sidorov  Владивосток   43   Менеджер
# 5      Кузнецов         Сочи   19    Рабочий
# 7  Котлеревский   Йошкар-Ола   32    Рабочий
# 8    Завалишина    Чебоксары   36   Менеджер

# %%
sample = pd.read_csv("sample.csv")
sample4=sample[~sample.City.str.contains("о",na=False)]
sample4
# Out:
#        Name    City  Age Profession
# 4   _______   Курск   50   Водитель
# 6     Сажин  Сургут   29    Рабочий
# 9    Левина     NaN   55    Рабочий
# 10     Фикс    Рига   42    Рабочий

# %%
log = pd.read_csv("log.csv",header=None)
log.columns = ['user_id','time', 'bet','win']
new_log=log[~log.user_id.str.contains("error", na=False)]
new_log
# Out:
#                               user_id                  time      bet     win
# 0    Запись пользователя № - user_919  [2019-01-01 14:06:51      NaN     NaN
# 1    Запись пользователя № - user_973  [2019-01-01 14:51:16      NaN     NaN
# 2    Запись пользователя № - user_903  [2019-01-01 16:31:16      NaN     NaN
# 3    Запись пользователя № - user_954  [2019-01-01 17:17:51      NaN     NaN
# 4    Запись пользователя № - user_954  [2019-01-01 21:31:18      NaN     NaN
# ..                                ...                   ...      ...     ...
# 991  Запись пользователя № - user_965  [2019-04-20 12:55:41    800.0  6927.0
# 992  Запись пользователя № - user_967  [2019-04-20 14:59:36  10154.0     NaN
# 993  Запись пользователя № - user_973  [2019-04-20 17:09:56  10254.0     NaN
# 994  Запись пользователя № - user_977  [2019-04-20 18:10:07  10354.0     NaN
# 995  Запись пользователя № - user_984   [2019-04-20 9:59:58   9754.0     NaN
#
# [985 rows x 4 columns]

# %%
sample = pd.read_csv("sample.csv")
sample2=sample
sample2['Age'] = sample['Age'].apply(lambda x: x + 1)
sample2
# Out:
#             Name         City  Age Profession
# 0         Иванов       Москва   26     Клинер
# 1            NaN    Волгоград   32   Менеджер
# 2         Иванов       Москва   26     Клинер
# 3        sidorov  Владивосток   44   Менеджер
# 4        _______        Курск   51   Водитель
# 5       Кузнецов         Сочи   20    Рабочий
# 6          Сажин       Сургут   30    Рабочий
# 7   Котлеревский   Йошкар-Ола   33    Рабочий
# 8     Завалишина    Чебоксары   37   Менеджер
# 9         Левина          NaN   56    Рабочий
# 10          Фикс         Рига   43    Рабочий

# %%
sample = pd.read_csv("sample.csv")
sample2=sample
sample2['City']=sample['City'].apply(lambda x:str(x).lower())
sample2
# Out:
#             Name         City  Age Profession
# 0         Иванов       москва   25     Клинер
# 1            NaN    волгоград   31   Менеджер
# 2         Иванов       москва   25     Клинер
# 3        sidorov  владивосток   43   Менеджер
# 4        _______        курск   50   Водитель
# 5       Кузнецов         сочи   19    Рабочий
# 6          Сажин       сургут   29    Рабочий
# 7   Котлеревский   йошкар-ола   32    Рабочий
# 8     Завалишина    чебоксары   36   Менеджер
# 9         Левина          nan   55    Рабочий
# 10          Фикс         рига   42    Рабочий

# %%
sample = pd.read_csv("sample.csv")
sample2 = sample.copy(deep=True)
def profession_code(s):
    if s == "Рабочий":
        return 0
    elif s == "Менеджер":
        return 1
    else:
        return 2
sample2.Profession.apply(profession_code)
# Out:
# 0     2
# 1     1
# 2     2
# 3     1
# 4     2
# 5     0
# 6     0
# 7     0
# 8     1
# 9     0
# 10    0
# Name: Profession, dtype: int64

# %%
def age_category(age):
    if age <23:
        return "молодой"
    elif (age >23) and (age<35):
        return "средний"
    elif age<35:
        return "зрелый"
sample['Age_category'] = sample.Age.apply(age_category)
sample
# Out:
#             Name         City  Age Profession Age_category
# 0         Иванов       Москва   25     Клинер      средний
# 1            NaN    Волгоград   31   Менеджер      средний
# 2         Иванов       Москва   25     Клинер      средний
# 3        sidorov  Владивосток   43   Менеджер         None
# 4        _______        Курск   50   Водитель         None
# 5       Кузнецов         Сочи   19    Рабочий      молодой
# 6          Сажин       Сургут   29    Рабочий      средний
# 7   Котлеревский   Йошкар-Ола   32    Рабочий      средний
# 8     Завалишина    Чебоксары   36   Менеджер         None
# 9         Левина          NaN   55    Рабочий         None
# 10          Фикс         Рига   42    Рабочий         None

# %%
log = pd.read_csv('log.csv', header=None)
log.columns = ['user_id','time','bet','win']
df = pd.DataFrame(log['user_id'])
def func(x):
    a=[]
    for i in x:
        if i=='#error':        
            a.append(i.replace('#error',''))
        else:
            a.append(i[i.find('user'):])
    return a
log['user_id'] =df.apply(func)
log
# Out:
#       user_id                  time      bet      win
# 0    user_919  [2019-01-01 14:06:51      NaN      NaN
# 1    user_973  [2019-01-01 14:51:16      NaN      NaN
# 2    user_903  [2019-01-01 16:31:16      NaN      NaN
# 3    user_954  [2019-01-01 17:17:51      NaN      NaN
# 4    user_954  [2019-01-01 21:31:18      NaN      NaN
# ..        ...                   ...      ...      ...
# 995  user_984   [2019-04-20 9:59:58   9754.0      NaN
# 996                             NaN  10054.0  29265.0
# 997                             NaN  10454.0      NaN
# 998                             NaN   1000.0      NaN
# 999                             NaN  10754.0      NaN
#
# [1000 rows x 4 columns]

# %%
log = pd.read_csv("log.csv",header=None) 
log.columns = ['user_id','time','bet','win']
t = log.time.apply(lambda x:str(x).replace('[','')) 
t[0]
# Out:
# '2019-01-01 14:06:51'

# %%
log = pd.read_csv('log.csv', header=None)
log.columns = ['user_id','time','bet','win']
log.time = log.time.apply(lambda x:str(x).replace('[','') if ('[' in str(x)) else x)
log.time
# Out:
# 0      2019-01-01 14:06:51
# 1      2019-01-01 14:51:16
# 2      2019-01-01 16:31:16
# 3      2019-01-01 17:17:51
# 4      2019-01-01 21:31:18
#               ...
# 995     2019-04-20 9:59:58
# 996                    NaN
# 997                    NaN
# 998                    NaN
# 999                    NaN
# Name: time, Length: 1000, dtype: object

# %%
log = pd.read_csv("log.csv",header=None) 
log.columns = ['user_id','time','bet','win']
t = log.time[0]
t1=t.apply(lambda x:str(x).replace('[',''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-af17fd5aa6ca> in <module>
#       2 log.columns = ['user_id','time','bet','win']
#       3 t = log.time[0]
# ----> 4 t1=t.apply(lambda x:str(x).replace('[',''))
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
log = pd.read_csv("log.csv",header=None) 
log.columns = ['user_id','time','bet','win']
new_log=log[~log.user_id.str.contains("error", na=False)]
df = pd.DataFrame(log['user_id'])
def func(x):
    a=[]
    for i in x:
        if i=='#error':        
            a.append(i.replace('#error',''))
        else:
            a.append(i[i.find('user'):])
    return a
log['user_id'] =df.apply(func)
log.time = log.time.apply(lambda x:str(x).replace('[','') if ('[' in str(x)) else x)
# Out:
# 0      2019-01-01 14:06:51
# 1      2019-01-01 14:51:16
# 2      2019-01-01 16:31:16
# 3      2019-01-01 17:17:51
# 4      2019-01-01 21:31:18
#               ...
# 995     2019-04-20 9:59:58
# 996                    NaN
# 997                    NaN
# 998                    NaN
# 999                    NaN
# Name: time, Length: 1000, dtype: object

# %%
sample = pd.read_csv("sample.csv")
sample2= sample.copy(deep=True)
sample2=sample2.Profession.apply(profession_code)
sample2
# Out:
# 0     2
# 1     1
# 2     2
# 3     1
# 4     2
# 5     0
# 6     0
# 7     0
# 8     1
# 9     0
# 10    0
# Name: Profession, dtype: int64
