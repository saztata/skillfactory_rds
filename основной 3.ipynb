# %%
proverb = 'Хорошо написанная программа - это программа, написанная 2 раза'

while True:
    index = proverb.find('программа')
    if index == -1:
        break
    secret = proverb[:index].split()[-1]
    proverb = proverb[index+9:] 
    print(secret)
# Out:
# написанная
# это

# %%
number = 56.257
a=str(number).split('.')[1]
number=int(a[0])+int(a[1])+int(a[2])
print(number)
# Out:
# 14

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']
emails_dict={}
a=b=c=1
for mails in emails_list:
    dom=mails.find('@')
    key=mails[dom+1:]
    if key=='mail.ru':
        emails_dict[key]=a
        a+=1
    elif key=='yandex.ru':
        emails_dict[key]=b
        b+=1
    elif key=='gmail.com':
        emails_dict[key]=c
        c+=1
    else:
        continue
emails_dict  
#Ключами словаря должны быть адреса доменов, а значениями — количество электронных адресов из списка emails_list, зарегистрированных на каждом домене.
# Out:
# {'mail.ru': 3, 'yandex.ru': 5, 'gmail.com': 2}

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']
emails_dict = dict()
emails_domains_list = list()
for item in emails_list:
    emails_domains_list.append(item[item.find('@')+1:])
import collections
how_many_domains = collections.Counter()
for unique_domain in emails_domains_list:
    how_many_domains[unique_domain] += 1
emails_dict = how_many_domains

# %%
string = 'Тяжёлая интернет-зависимость - это когда ты выходишь из интернета, а он из тебя нет.'
newstring=''
for i in string:
    if i=='.' or i==',' or i==':' or i=='-'or i=='!'or i=='?':
        string=string.replace(i,':)')
print(string)
# Out:
# Тяжёлая интернет:)зависимость :) это когда ты выходишь из интернета:) а он из тебя нет:)

# %%
name = 'Севастиан'
for i in name:
    if i in('а','е','и'):
        print(i,'- гласная буква')
    else:
        print(i,'- согласная буква')
# Out:
# С - согласная буква
# е - гласная буква
# в - согласная буква
# а - гласная буква
# с - согласная буква
# т - согласная буква
# и - гласная буква
# а - гласная буква
# н - согласная буква

# %%
import re 
pattern = re.compile('[АИОУЕЁЮЭЫЯаиоуеёюэыя]\s[бвгджзйклмнпрстфхцчшщьъБВГДЖЗЙКЛМНПРСТФХЦШЩЬЪ]')
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'
pattern.search(text)
pattern.findall(text)
# Out:
# ['а н',
#  'а в',
#  'о в',
#  'я р',
#  'я р',
#  'и Г',
#  'о н',
#  'а д',
#  'е н',
#  'и д',
#  'о н',
#  'е п',
#  'а Г',
#  'е н',
#  'а п',
#  'о в',
#  'е н',
#  'а п',
#  'о б',
#  'о к',
#  'о т',
#  'и П']

# %%
f = open('StudentsPerformance.csv') 
for line in f:
         print(line)
f.close()
# Out:
# "gender","race/ethnicity","parental level of education","lunch","test preparation course","math score","reading score","writing score"
#
# "female","group B","bachelor's degree","standard","none","72","72","74"
#
# "female","group C","some college","standard","completed","69","90","88"
#
# "female","group B","master's degree","standard","none","90","95","93"
#
# "male","group A","associate's degree","free/reduced","none","47","57","44"
#
# "male","group C","some college","standard","none","76","78","75"
#
# "female","group B","associate's degree","standard","none","71","83","78"
#
# "female","group B","some college","standard","completed","88","95","92"
#
# "male","group B","some college","free/reduced","none","40","43","39"
#
# "male","group D","high school","free/reduced","completed","64","64","67"
#
# "female","group B","high school","free/reduced","none","38","60","50"
#
# "male","group C","associate's degree","standard","none","58","54","52"
#
# ...

# %%
f = open('StudentsPerformance.csv')
males = 0
females = 0
for line in f:
    info = line.split(',')
    gender = info[0][1:-1]
    if gender == 'female':
        females += 1
    elif gender == 'male':
        males +=1
print('Мальчиков: {}, девочек: {}'.format(males, females))
# Out:
# Мальчиков: 482, девочек: 518

# %%
f = open('StudentsPerformance.csv')
dip=[]
for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    g = info[2][1:-1]
    if g not in dip:
        dip.append(g)
print(len(dip))
# Out:
# 6

# %%
f = open('StudentsPerformance.csv')
lan = 0
d=[]
for line in f:
    info = line.split(',')
    gender = info[1][1:-1]
    if 'C'in gender:
        d.append(gender)
        a=len(d)
print(a)
# Out:
# 319

# %%
f = open('StudentsPerformance.csv')
lan = 0
d=[]
for line in f:
    info = line.split(',')
    gender = info[3][1:-1]
    d.append(gender)
    a=len(d)
    if gender == 'standard':
        lan += 1
print(lan/a)
# Out:
# 0.6443556443556444

# %%
f = open('StudentsPerformance.csv')
lan = 0
d=[]
for line in f:
    info = line.split(',')
    gender = info[1][1:-1]
    d.append(gender)
    a=len(d)
print(a)
# Out:
# 1001

# %%
f = open('StudentsPerformance.csv')
lis=[]
for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    g1 = info[1][7:-1]
    if g1 not in lis:
        lis.append(g1)
print(len(lis))
# Out:
# 5

# %%
math = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        mark = int(info[5][1:-1])
        math.append(mark) 
#Имея данные обо всех оценках, мы можем, например, посчитать средний балл:        
math_avg = sum(math)/len(math)
#и даже найти долю абитуриентов, показавших результат выше среднего:
above_avg = 0
for mark in math:
    if mark > math_avg:
        above_avg += 1
print(above_avg / 1000)
# Out:
# 0.493

# %%
import re
pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        new_line = []
        for item in info:
            if pattern.search(item) != None:
                new_line.append(int(pattern.search(item)[0]))
            else:
                new_line.append(item[1:-1])
        exams.append(new_line)
print(exams)        
#Создаём паттерн, описывающий строку, состоящую только из цифр.
#Создаём пустой список (exams), в который будем помещать данные.
#Открываем файл.
#Начинаем построчный перебор содержимого файла с помощью цикла с параметром.
#Преобразуем содержимое строки в список (info), и если первым элементом списка является значение «"gender"», пропускаем все остальные действия.
#Создаём временный пустой список (new_line), в который мы будем помещать обработанные (лишённые кавычек и преобразованные в нужный формат) элементы строки.
#Организуем вложенный цикл с параметром и последовательно перебираем в нём элементы строки info.
#Проверяем, совпадает ли содержимое текущего элемента списка info с созданным нами паттерном (набор цифр).
#Если текущий элемент строки содержит цифры (метод pattern.search(item) не возвращает значение  None) , извлекаем из обрабатываемого элемента строку, соответствующую паттерну (pattern.search(item)[0]), преобразуем ее в тип int и добавляем к списку new_line; иначе добавляем к списку new_line текущее значение параметра цикла без первого и последнего символов.
#Добавляем список new_line к итоговому списку exams.
# Out:
# [['female', 'group B', "bachelor's degree", 'standard', 'none', 72, 72, 74], ['female', 'group C', 'some college', 'standard', 'completed', 69, 90, 88], ['female', 'group B', "master's degree", 'standard', 'none', 90, 95, 93], ['male', 'group A', "associate's degree", 'free/reduced', 'none', 47, 57, 44], ['male', 'group C', 'some college', 'standard', 'none', 76, 78, 75], ['female', 'group B', "associate's degree", 'standard', 'none', 71, 83, 78], ['female', 'group B', 'some college', 'standard', 'completed', 88, 95, 92], ['male', 'group B', 'some college', 'free/reduced', 'none', 40, 43, 39], ['male', 'group D', 'high school', 'free/reduced', 'completed', 64, 64, 67], ['female', 'group B', 'high school', 'free/reduced', 'none', 38, 60, 50], ['male', 'group C', "associate's degree", 'standard', 'none', 58, 54, 52], ['male', 'group D', "associate's degree", 'standard', 'none', 40, 52, 43], ['female', 'group B', 'high school', 'standard', 'none', 65, 81, 73], ['male', 'group A', 'some 
# ...

# %%
import re
pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        new_line = []
        for item in info:
            if pattern.search(item) != None:
                new_line.append(int(pattern.search(item)[0]))
            else:
                new_line.append(item[1:-1])
        exams.append(new_line)
srb=0
for i in range(0,len(exams)):
    srb+=exams[i][6]
nizsr=srb/len(exams)
collabitur=0
for i in range(0,len(exams)):
    if exams[i][6]<nizsr:
        collabitur+=1 
print(collabitur)
# Out:
# 487

# %%
import re
pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        new_line = []
        for item in info:
            if pattern.search(item) != None:
                new_line.append(int(pattern.search(item)[0]))
            else:
                new_line.append(item[1:-1])
        exams.append(new_line)
srb=0
colldev=0
for i in range(0,len(exams)):
    if exams[i][0]=='male':
        srb+=exams[i][6]
        colldev+=1
print(srb/colldev)
# Out:
# 65.47302904564316

# %%
import re
pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        new_line = []
        for item in info:
            if pattern.search(item) != None:
                new_line.append(int(pattern.search(item)[0]))
            else:
                new_line.append(item[1:-1])
        exams.append(new_line)
kol=0
for i in range(0,len(exams)):
    if exams[i][7]>90:
        kol+=1
print(kol)
# Out:
# 68

# %%
import re
pattern = re.compile('\d+')

exams = []

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        new_line = []
        for item in info:
            if pattern.search(item) != None:
                new_line.append(int(pattern.search(item)[0]))
            else:
                new_line.append(item[1:-1])
        exams.append(new_line)
koll=0
for i in range(0,len(exams)):
    if exams[i][7]>90 and exams[i][3]=='standard':
        koll+=1
print(koll/68)
# Out:
# 0.8676470588235294

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
#Создадим пустой словарь (students), в котором будем накапливать данные.
#Откроем файл для чтения из него данных.
#Начнем построчно перебирать файл с помощью цикла с параметром.
#Преобразуем очередную строку в список и смотрим, чему равен её первый элемент.
#Если элемент содержит заголовок первого столбца, то мы пропускаем последующие действия. 
#Если обрабатываемая строка не заголовок, то мы извлекаем из неё данные об этнической группе,
#к которой принадлежит студент, и присваиваем эту информацию, отбросив лишние кавычки, переменной ethnicity:
if ethnicity in students:
    students[ethnicity] += 1
else:
    students[ethnicity] = 1
print(students)
# Out:
# {'group D': 1}

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        if ethnicity in students:
            students[ethnicity] += 1
        else:
            students[ethnicity] = 1
print(students)
# Out:
# {'group B': 190, 'group C': 319, 'group A': 89, 'group D': 262, 'group E': 140}

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[1][1:-1]
        parents = info[2][1:-1]
        if ethnicity in students:
            if parents in students[ethnicity]:
                students[ethnicity][parents] += 1
            else:
                students[ethnicity][parents] = 1
        else:
            students[ethnicity] = {}
            students[ethnicity][parents] = 1            
print(students)
# Out:
# {'group B': {"bachelor's degree": 20, "master's degree": 6, "associate's degree": 41, 'some college': 37, 'high school': 48, 'some high school': 38}, 'group C': {'some college': 69, "associate's degree": 78, 'some high school': 49, 'high school': 64, "master's degree": 19, "bachelor's degree": 40}, 'group A': {"associate's degree": 14, 'some college': 18, "master's degree": 3, 'some high school': 24, "bachelor's degree": 12, 'high school': 18}, 'group D': {'high school': 44, "associate's degree": 50, 'some college': 67, "bachelor's degree": 28, "master's degree": 23, 'some high school': 50}, 'group E': {"master's degree": 8, 'some college': 35, "associate's degree": 39, "bachelor's degree": 18, 'some high school': 18, 'high school': 22}}

# %%
students = {}

f = open('StudentsPerformance.csv')

for line in f:
    info = line.split(',')
    if info[0] == '"gender"':
        continue
    else:
        ethnicity = info[0][1:-1]
        parents = info[2][1:-1]
        if ethnicity in students:
            if parents in students[ethnicity]:
                students[ethnicity][parents] += 1
            else:
                students[ethnicity][parents] = 1
        else:
            students[ethnicity] = {}
            students[ethnicity][parents] = 1            
print(students)
# Out:
# {'female': {"bachelor's degree": 63, 'some college': 118, "master's degree": 36, "associate's degree": 116, 'high school': 94, 'some high school': 91}, 'male': {"associate's degree": 106, 'some college': 108, 'high school': 102, "master's degree": 23, "bachelor's degree": 55, 'some high school': 88}}

# %%
def square(x):
    return x**2
square_result=square(20)
print(square_result)
# Out:
# 400

# %%
def sum_2(x,y):
    result = x+y
    return result
sum_2(42,73)
print(sum_2(42, 73))
# Out:
# 115

# %%
def get_median(listt):
    listt=sorted(listt)
    length=len(listt)
    if length%2==0:
        index=int(length/2)
        return int((listt[index]+listt[index-1])/2)
    else:
        return listt[int(length / 2)]
ads=[3, 3, 7, 9]   
d=get_median(ads)   
print(d)
# Out:
# 5

# %%
def get_median(l):
    lt=sorted(l)
    length=len(l)
    if length%2==0:
        index=(length/2)
        return ((l[index]+l[index-1])/2)
    else:
        return (l(length / 2))  
l=[1,3,5,6]
a=get_median(l)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-cd4bad227470> in <module>
#       8         return (l(length / 2))
#       9 l=[1,3,5,6]
# ---> 10 a=get_median(l)
#      11 print(a)
#
# <ipython-input-33-cd4bad227470> in get_median(l)
#       4     if length%2==0:
#       5         index=(length/2)
# ----> 6         return ((l[index]+l[index-1])/2)
#       7     else:
#       8         return (l(length / 2))
#
# TypeError: list indices must be integers or slices, not float

# %%
user_db = [{'orders': 12}, {'orders': 30}, {'orders': 45}]

# перепишите эту часть
def avg_orders(user):
    order_sum = sum([item['orders'] for item in user])
    return(order_sum/len(user))
avg_orders(user_db)
# Out:
# 29.0

# %%
def to_euro(price):  
    exchange_rate = 70  
    rounded = round(price/exchange_rate, 2)  
    return '€' + str(rounded)  
  
def db_to_euro(db):  
    return [to_euro(item['price']) for item in db]  
ticket_db = [{'price': 400}, {'price': 200}, {'price': 150}]  
guide_db = [{'price': 50}, {'price': 40}]  
snack_db = [{'price': 100}, {'price': 95}, {'price': 150}]  
  
tickets_euro = db_to_euro(ticket_db)  
guides_euro = db_to_euro(guide_db)  
snacks_euro = db_to_euro(snack_db)  
  
print(tickets_euro, guides_euro, snacks_euro)
# Out:
# ['€5.71', '€2.86', '€2.14'] ['€0.71', '€0.57'] ['€1.43', '€1.36', '€2.14']

# %%
def get_euro_rate():
    from random import random
    return (65+random()*20)


# используйте get_euro_rate в следующей функции
def to_euro(price):  
    exchange_rate = get_euro_rate()  
    rounded = round(price/exchange_rate, 2)  
    return '€' + str(rounded)
to_euro(80)
# Out:
# '€1.01'

# %% [raw]
# all_the = sum
# magic = range
# print(all_the(magic(5)))

# %%
list(map(abs, [10,  -1, 42, -73]))[3]
# Out:
# 73

# %%
values = [1, 2, 3]
vectors = [(10, 3), (4, 5), (6, 7)]
map(lambda x, y: x + y, values)

# %%
values = [4, 8, 15, 16, 23, 42]
mean = 18
result =list( map(lambda x: x-mean, values))
print(result)
# Out:
# [-14, -10, -3, -2, 5, 24]

# %%
values = [4, 8, 15, 16, 23, 42]
mean = 18
result = list(filter( lambda x: x>mean, values))
print(result)
# Out:
# [23, 42]

# %%
std = 42 

def normalize(value):
    result = value/std
    return result 
    
print(normalize(21))
# Out:
# 0.5

# %%
rabbits = 0

def count_rabbits(spotted):
    global rabbits
    rabbits += spotted

    
count_rabbits(3)
count_rabbits(5)
print(rabbits)
# Out:
# 8

# %%
norm=[]
def normalize(numbers, mean=0, std=1):
    norm=[]
    for num in numbers:
        norm.append(int((num-mean)/std))
    return norm
normalize([10, 20], std=2)
# Out:
# [5, 10]

# %%
def multiply(*args):  
    product = 1  
    for num in args:  
        product *= num  
    return product   
  
print(multiply(2))  
# => 2  
print(multiply(8, 3, 4))  
# => 96  
print(multiply(1, 2, 3, 4, 5, 6))  
# => 720
# Out:
# 2
# 96
# 720

# %%
def sum_args (*args):
    product1=0
    for nums in args:
        product1+=nums
    return product1
print(sum_args(10,15,-4))
# Out:
# 21

# %%
def show_keys(**kwargs):
    print(' '.join(kwargs.keys()))

show_keys(verbose=True, mode='constant')
# Out:
# verbose mode

# %%
def count_letters(sentence,average=0):   
    count=0
    nor=[]
    for letter in sentence:
        s=sentenses.split('')
        nor=nor.append(letter)
        if letter!='':
            count+=1
    return count 
print(s)
#count_letters("Beep boop") # => 8
#count_letters("Beep boop", average=True) # => 4
#count_letters("I will build my own theme park") # => 24
#count_letters("I will build my own theme park", average=True) # => 3.429
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-8aab53876b1e> in <module>
#       8             count+=1
#       9     return count
# ---> 10 print(s)
#      11 #count_letters("Beep boop") # => 8
#      12 #count_letters("Beep boop", average=True) # => 4
#
# NameError: name 's' is not defined

# %%
def always(n=5):
    def func():
        return n
    return func
five = always(5)
five()
# Out:
# 5

# %%
words = ["sofa", "suitcase", "valise", "picture", "basket", "carton", "doggie"]
list(map(lambda w: sorted(w)[0], words))[5]
# Out:
# 'a'

# %%
def count_letters(sentence, average=False):
    count=0
    s=sentence.split(' ')
    x=list(map(len,s))
    print(x)
    if average==False:
        return(sum(x))
    else:
        return(sum(x)/len(x))
count_letters("Beep boop")
# Out:
# [4, 4]
# 8

# %%
def count_letters(sentence, average=False):
    count=0
    s=sentence.split(' ')
    x=list(map(len,s))
    print(x)
    if average==False:
        return(sum(x))
    else:
        return(sum(x)/len(x))
#count_letters("Beep boop", average=True) # => 4
#count_letters("I will build my own theme park") # => 24
count_letters("I will build my own theme park", average=True) # => 3.429
# Out:
# [1, 4, 5, 2, 3, 5, 4]
# 3.4285714285714284
