# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

pd.set_option('display.max_rows', 50) # показывать больше строк
pd.set_option('display.max_columns', 50) # показывать больше колонок

math = pd.read_csv('stud_math.csv')
display(math.head(10))
math.info()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0   at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0   at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0   at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0    health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0     other    other
# 5     GP   M   16       U     LE3       T   4.0   3.0  services    other
# 6     GP   M   16     NaN     LE3       T   2.0   2.0     other    other
# 7     GP   F   17       U     GT3       A   4.0   4.0     other  teacher
# 8     GP   M   15       U     LE3       A   3.0   2.0  services    other
# 9     GP   M   15       U     NaN     NaN   3.0   4.0     other    other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0      course   mother         2.0        2.0       0.0       yes     no   no
# ...

# %% [markdown]
# Рассмотрим датасет. Посмотрим данные - каждый столбец на наличие пустых строк и рассмотрим категории столюцов!

# %%
math.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score'],
#       dtype='object')

# %% [markdown]
# Переименуем столбцы

# %%
math=math.rename(columns={'Pstatus':'status','Medu':'medu','Fedu':'fedu','Mjob':'mjob','Fjob':'fjob','studytime, granular':'studytime_granular'})
math.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'status', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime_granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score'],
#       dtype='object')

# %% [markdown]
# Напишем функцию для поиска пустых значений
# Тут ВСЕ

# %%
math.score = math.score.apply(lambda x:None if x == ''  else x)
display(pd.DataFrame(math.score.value_counts()))
print("учеников, у которых бал ниже 50:"#Число 10 взято для ориентира, можно брать другое
      , (math.score.value_counts()<50).sum())
math.loc[:, ['score']].info()
# Out:
#        score
# 50.0      54
# 55.0      46
# 0.0       37
# 75.0      33
# 65.0      31
# 40.0      31
# 60.0      31
# 70.0      27
# 45.0      27
# 80.0      16
# 30.0      15
# 90.0      12
# 35.0       9
# 25.0       7
# 85.0       6
# 95.0       5
# 100.0      1
# 20.0       1
# учеников, у которых бал ниже 50: 17
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   score   389 non-null    float64
# dtypes: float64(1)
# memory usage: 3.2 KB

# %%
def count_unique(columns):
    print(math.columns.nunique())
    plt.plot(columns)

# %%
for col in ['score']:
    count_unique(col)
# Out:
# 30

# %% [markdown]
# Попробуем отфильтровать лишние данные и выведем только те компании, у которых непустые значения

# %%
math.address = math.address.apply(lambda x: None if x == '' else x)
display(pd.DataFrame(math.address.value_counts()))
print("Ненулевых значений:"#Число 10 взято для ориентира, можно брать другое
      , (math.address.value_counts()).sum())
math.loc[:, ['address']].info()
# Out:
#    address
# U      295
# R       83
# Ненулевых значений: 378
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   address  378 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# Этот столбец числовой и без пропусков. Поэтому посмотрим на его распределение:

# %%
math.school.hist()
math.school.describe()
# Out:
# count     395
# unique      2
# top        GP
# freq      349
# Name: school, dtype: object

# %% [markdown]
# Напишем функцию для заполнения пропусков нечисловых столбцов

# %%
def fill_pass_str(columns):
    math.columns = math.columns.fillna(math.columns.mode()[0])
    pd.DataFrame(math.columns.value_counts())
    display(math.head(10))
    math.info()

# %%
fill_pass_str('sex')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-4e45060b18c6> in <module>
# ----> 1 fill_pass_str('sex')
#
# <ipython-input-38-fc1f0a8c8f18> in fill_pass_str(columns)
#       1 def fill_pass_str(columns):
# ----> 2     math.columns = math.columns.fillna(math.columns.mode()[0])
#       3     pd.DataFrame(math.columns.value_counts())
#       4     display(math.head(10))
#       5     math.info()
#
# AttributeError: 'Index' object has no attribute 'mode'

# %%
for col in ['school', 'sex', 'address', 'famsize', 'status',
       'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    fill_pass_str(col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-66f7f4b4119b> in <module>
#       1 for col in ['school', 'sex', 'address', 'famsize', 'status',
#       2        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
# ----> 3     fill_pass_str(col)
#
# <ipython-input-113-fad9cd528402> in fill_pass_str(columns)
#       2
#       3     pd.DataFrame(math.columns.value_counts())
# ----> 4     math.columns = math.columns.fillna(math.columns.mode()[0])
#       5     display(math.head(10))
#       6     math.info()
#
# AttributeError: 'Index' object has no attribute 'mode'

# %% [markdown]
# Напишем функцию заполнения пропусков числовых столбцов

# %%
math.freetime = math.freetime.fillna (math.freetime.mode())
pd.DataFrame(math.freetime.value_counts())
math.freetime = math.freetime.fillna(math.freetime.mode())
display(math.head(10))
math.info()
# Out:
#   school sex  age address famsize status  medu  fedu      mjob     fjob  \
# 0     GP   F   18       U     NaN      A   4.0   4.0   at_home  teacher
# 1     GP   F   17       U     GT3    NaN   1.0   1.0   at_home    other
# 2     GP   F   15       U     LE3      T   1.0   1.0   at_home    other
# 3     GP   F   15       U     GT3      T   4.0   2.0    health      NaN
# 4     GP   F   16       U     GT3      T   3.0   3.0     other    other
# 5     GP   M   16       U     LE3      T   4.0   3.0  services    other
# 6     GP   M   16       U     LE3      T   2.0   2.0     other    other
# 7     GP   F   17       U     GT3      A   4.0   4.0     other  teacher
# 8     GP   M   15       U     LE3      A   3.0   2.0  services    other
# 9     GP   M   15       U     NaN    NaN   3.0   4.0     other    other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0      course   mother         2.0        2.0       0.0       yes     no   no
# ...

# %%
def fill_pass(columns):
    math.columnse = math.columns.fillna (math.columns.mode())
    pd.DataFrame(math.columns.value_counts())
    math.columns = math.columns.fillna(math.columns.mode())
    display(math.head(10))
    math.info()

# %%
for col in ['medu']:
    fill_pass(col)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-77939fce1ecc> in <module>
#       1 for col in ['medu']:
# ----> 2     fill_pass(col)
#
# <ipython-input-124-c4a986124f2f> in fill_pass(columns)
#       1 def fill_pass(columns):
# ----> 2     math.columnse = math.columns.fillna (math.columns.mean())
#       3     pd.DataFrame(math.columns.value_counts())
#       4     math.columns = math.columns.fillna(math.columns.mean())
#       5     display(math.head(10))
#
# AttributeError: 'Index' object has no attribute 'mean'

# %%
print(math.freetime.nunique())
plt.plot(math.freetime)
# Out:
# 6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-5491948fcc26> in <module>
#       1 print(math.freetime.nunique())
# ----> 2 plt.plot(math.freetime)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
# -> 1667             self.add_line(line)
#    1668         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1669         return lines
#
# ...

# %%
pd.DataFrame(math.sex.value_counts())
# Out:
#    sex
# F  208
# M  187

# %%
pd.DataFrame(math.age.value_counts())
# Out:
#     age
# 16  104
# 17   98
# 18   82
# 15   82
# 19   24
# 20    3
# 22    1
# 21    1

# %%
math.famsize.hist()
math.famsize.describe()
# Out:
# count     368
# unique      2
# top       GT3
# freq      261
# Name: famsize, dtype: object

# %%
pd.DataFrame(math.score.value_counts())
# Out:
#        score
# 50.0      54
# 55.0      46
# 0.0       37
# 75.0      33
# 65.0      31
# 40.0      31
# 60.0      31
# 70.0      27
# 45.0      27
# 80.0      16
# 30.0      15
# 90.0      12
# 35.0       9
# 25.0       7
# 85.0       6
# 95.0       5
# 100.0      1
# 20.0       1

# %%
math.score
# Out:
# 0      30.0
# 1      30.0
# 2      50.0
# 3      75.0
# 4      50.0
#        ...
# 390    45.0
# 391    80.0
# 392    35.0
# 393    50.0
# 394    45.0
# Name: score, Length: 395, dtype: float64

# %%
math.score.hist()
math.score.describe()
# Out:
# count    389.000000
# mean      52.262211
# std       22.919022
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %%
math.score = math.score.apply(lambda x: None if x == '' else x)
display(pd.DataFrame(math.score.value_counts()))
# Out:
#        score
# 50.0      54
# 55.0      46
# 0.0       37
# 75.0      33
# 65.0      31
# 40.0      31
# 60.0      31
# 70.0      27
# 45.0      27
# 80.0      16
# 30.0      15
# 90.0      12
# 35.0       9
# 25.0       7
# 85.0       6
# 95.0       5
# 100.0      1
# 20.0       1

# %%
math.score.hist()
math.score.describe()
math.score = math.score.apply(lambda x: None if x == '' else x)

# %%
median = math.score.median()
IQR = math.score.quantile(0.75) - math.score.quantile(0.25)
perc25 = math.score.quantile(0.25)
perc75 = math.score.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75)
      , "IQR: {}, ".format(IQR),"Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
math.score.loc[math.score.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins = 16
                                                                                              , range = (40, 100), 
                                                                                             label = 'IQR')
math.score.loc[math.score <= 100].hist(alpha = 0.5, bins = 16, range = (40, 100),
                                                        label = 'Здравый смысл')
plt.legend();
# Out:
# 25-й перцентиль: 40.0, 75-й перцентиль: 70.0, IQR: 30.0,  Границы выбросов: [-5.0, 115.0].

# %%
sns.pairplot(math, kind = 'reg')

# %%
math.corr()
# Out:
#                          age      medu      fedu  traveltime  studytime  \
# age                 1.000000 -0.161704 -0.138018    0.081508  -0.015556
# medu               -0.161704  1.000000  0.275598   -0.173515   0.078589
# fedu               -0.138018  0.275598  1.000000    0.030646   0.057199
# traveltime          0.081508 -0.173515  0.030646    1.000000  -0.102206
# studytime          -0.015556  0.078589  0.057199   -0.102206   1.000000
# failures            0.228047 -0.245463 -0.150821    0.064699  -0.178992
# studytime_granular  0.015556 -0.078589 -0.057199    0.102206  -1.000000
# famrel              0.068899 -0.010050  0.040577   -0.016857   0.045894
# freetime            0.029023  0.025335 -0.066556   -0.021937  -0.121969
# goout               0.135107  0.064164 -0.023282    0.037636  -0.051280
# health             -0.065946 -0.045051  0.027251   -0.021531  -0.080016
# absences            0.093592 -0.011944  0.004695   -0.048215  -0.026544
# ...

# %%
print(cacao.bar_id.nunique())
plt.plot(cacao.bar_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-11b2ab88cdef> in <module>
# ----> 1 print(cacao.bar_id.nunique())
#       2 plt.plot(cacao.bar_id)
#
# NameError: name 'cacao' is not defined
