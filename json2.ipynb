# %%
import json  
from pprint import pprint 
with open('recipes.json') as f:
    recipes = json.load(f)

# %%
import pandas as pd
df = pd.DataFrame(recipes)

# %%
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
def find_item(cell):
    if item in cell:
        return 1
    return 0

# %%
ingredients = list(df.columns[3:])

# %%
for item in ingredients:
    df[item] = df['ingredients'].apply(find_item)

# %%
df['ingredients'] = df['ingredients'].apply(lambda x: len(x))

# %%
df
# Out:
#         id      cuisine  ingredients
# 0    10259        greek            9
# 1    25693  southern_us           11
# 2    20130     filipino           12
# 3    22213       indian            4
# 4    13162       indian           20
# ..     ...          ...          ...
# 495   1121      chinese            9
# 496  18376      italian            8
# 497  17815      italian            8
# 498  32878  southern_us           19
# 499  24410      british           17
#
# [500 rows x 3 columns]

# %%
df.to_csv('recipes.csv', index = False)

# %%
df = pd.read_csv('recipes.csv')

# %%
ids = pd.Series(df.id.values).tolist()
ingredients = df.columns[3:].tolist()
new_recipes = []
for current_id in ids:
    recipe_id = int(current_id)
    recipe_cuisine = df[df['id'] == recipe_id]['cuisine'].iloc[0]
    recipe_ingredients = df[df['id'] == recipe_id].columns[df[df['id'] == recipe_id].apply(lambda x: True if x.iloc[0]==1 else False, axis=0)].tolist()
    recipe = {'cuisine': recipe_cuisine, 'id': recipe_id, 'ingredients': recipe_ingredients}
    new_recipes.append(recipe)

# %%
data = pd.read_excel('Fig3-1.xls')

# %%
data
# Out:
#     U.S. Home Price and Related data, for Figure 3.1 in Robert J. Shiller, Irrational Exuberance, 3rd. Edition, Princeton University Press, 2015, as updated by author  \
# 0                See the book for description of data.
# 1    Monthly data from January 1953 for prices, all...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 858                                            2018.79
# 859                                            2018.87
# 860                                            2018.96
# 861                                            2019.04
# 862                                                NaN
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2         Real        NaN       Real
# 3         Home        NaN   Building
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
data_file = pd.ExcelFile('./Fig3-1.xls')  
data = pd.read_excel(data_file, header=None)

# %%
with pd.ExcelFile('path_to_file.xls') as xls:  
    data['Sheet1'] = pd.read_excel(xls, 'Sheet1', na_values=['NA'])  
    data['Sheet2'] = pd.read_excel(xls, 'Sheet2')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-ba6901bae66d> in <module>
# ----> 1 with pd.ExcelFile('path_to_file.xls') as xls:
#       2     data['Sheet1'] = pd.read_excel(xls, 'Sheet1', na_values=['NA'])
#       3     data['Sheet2'] = pd.read_excel(xls, 'Sheet2')
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
#     822
#     823     def __fspath__(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ...

# %%
with pd.ExcelFile('path_to_file.xls') as xls:  
    data['Sheet1'] = pd.read_excel(xls, 'Sheet1')  
    data['Sheet2'] = pd.read_excel(xls, 'Sheet2')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-f04aa6458b4d> in <module>
# ----> 1 with pd.ExcelFile('path_to_file.xls') as xls:
#       2     data['Sheet1'] = pd.read_excel(xls, 'Sheet1')
#       3     data['Sheet2'] = pd.read_excel(xls, 'Sheet2')
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# --> 821         self._reader = self._engines[engine](self._io)
#     822
#     823     def __fspath__(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ...

# %%
data = pd.read_excel('path_to_file.xls', ['Sheet1', 'Sheet2'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-32e67a001050> in <module>
# ----> 1 data = pd.read_excel('path_to_file.xls', ['Sheet1', 'Sheet2'])
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
#     819         self._io = stringify_path(io)
#     820
# ...
